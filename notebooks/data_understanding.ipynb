# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime


df_schema2024 = pd.read_csv('../data/raw/7YearsStackoverflow/stack-overflow-developer-survey-2024/survey_results_schema.csv')
df_public2024 = pd.read_csv('../data/raw/7YearsStackoverflow/stack-overflow-developer-survey-2024/survey_results_public.csv')
df_schema2023 = pd.read_csv('../data/raw/7YearsStackoverflow/stack-overflow-developer-survey-2023/survey_results_schema.csv')
df_public2023 = pd.read_csv('../data/raw/7YearsStackoverflow/stack-overflow-developer-survey-2023/survey_results_public.csv')
df_schema2024.head()
# Out:
#        qid              qname  \
# 0     QID2         MainBranch
# 1   QID127                Age
# 2   QID296         Employment
# 3   QID308         RemoteWork
# 4   QID341              Check
# 5   QID297   CodingActivities
# 6    QID25            EdLevel
# 7   QID276          LearnCode
# 8   QID281    LearnCodeOnline
# 9   QID331            TechDoc
# 10   QID32          YearsCode
# 11   QID34       YearsCodePro
# 12   QID31            DevType
# 13   QID29            OrgSize
# 14  QID278  PurchaseInfluence
# 15  QID279         BuyNewTool
# 16  QID330         BuildvsBuy
# 17  QID335        TechEndorse
# 18    QID6            Country
# 19   QID50           Currency
# 20   QID51          CompTotal
# 21  QID233           Language
# 22  QID262           Database
# 23  QID263           Platform
# 24  QID264           Webframe
# 25  QID340           Embedded
# 26  QID265           MiscTech
# 27  QID275          ToolsTech
# 28  QID274     NEWCollabTools
# 29   QID71              OpSys
# ...

# %%
df_public2024.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# ## Data Understanding
#
# before we clean the data we should analayze which data is provided and which type of data should we extract to answer our questions. So let's start by getting the headers of the columns and analyze which Columns are important to answer our Question.
#
# 1. What does the gender distribution in the developer community look like, and has diversity improved over time?
# 2. How have the most in-demand skills in the job market changed over time?
# 3. Which technologies or frameworks are considered "most loved" or "most dreaded" by developers, and how have these trends evolved over the years?
#
# For Question 1 we need informations like

# %%
df_public2024.columns.values.tolist()

# %%
df_public2023.columns.values.tolist()
